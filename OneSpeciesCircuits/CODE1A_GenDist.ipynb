# %%
# Import packages
import importlib
import os
import time
import numpy as np
import gc
import mosa
from paretoset import paretoset
from matplotlib import cm
import matplotlib.pyplot as plt
from pymoo.indicators.gd import GD

# %%
# Import grid search data
gridsearchdata = np.load('../GridSearchData/ARneg_SensitivityPareto.npy')
gridsearchdata
# Out:
# array([[9.95024511e-01, 7.32168522e-05],
#        [9.47420408e-01, 7.36733243e-04],
#        [9.04110837e-01, 1.28221871e-03],
#        [8.64546123e-01, 1.73212713e-03],
#        [1.64980976e-01, 2.04773367e-03],
#        [1.44773238e-01, 3.13873615e-02],
#        [1.33331619e-01, 5.36538436e-02],
#        [1.25970918e-01, 7.15047887e-02],
#        [1.20835326e-01, 8.63639877e-02],
#        [1.17045572e-01, 9.90715702e-02],
#        [1.14131817e-01, 1.10161386e-01],
#        [1.11820295e-01, 1.19992519e-01],
#        [1.09940702e-01, 1.28817521e-01],
#        [1.08381528e-01, 1.36820498e-01],
#        [1.07066687e-01, 1.44139646e-01],
#        [1.05942478e-01, 1.50881267e-01],
#        [1.04969904e-01, 1.57128832e-01],
#        [1.04119960e-01, 1.62949053e-01],
#        [1.03370620e-01, 1.68396065e-01],
#        [1.02704852e-01, 1.73514391e-01],
#        [1.02109279e-01, 1.78341079e-01],
#        [1.01573245e-01, 1.82907281e-01],
#        [1.01088155e-01, 1.87239438e-01],
#        [1.00647001e-01, 1.91360177e-01],
#        [1.00244009e-01, 1.95289012e-01],
#        [9.98743776e-02, 1.99042886e-01],
#        [9.95340841e-02, 2.02636606e-01],
#        [9.92197295e-02, 2.06083179e-01],
#        [9.89284232e-02, 2.09394101e-01],
#        [9.86576907e-02, 2.12579572e-01],
#        [9.84054013e-02, 2.15648692e-01],
#        [9.81697104e-02, 2.18609607e-01],
#        [9.79490125e-02, 2.21469640e-01],
#        [9.77419039e-02, 2.24235399e-01],
#        [9.75471516e-02, 2.26912863e-01],
#        [9.73636684e-02, 2.29507463e-01],
#        [9.71904916e-02, 2.32024147e-01],
#        [9.70267658e-02, 2.34467433e-01],
#        [9.68717281e-02, 2.36841457e-01],
#        [9.67246961e-02, 2.39150018e-01],
#        [9.65850575e-02, 2.41396611e-01],
#        [9.64522613e-02, 2.43584460e-01],
#        [9.63258099e-02, 2.45716542e-01],
#        [9.62052536e-02, 2.47795618e-01],
#        [9.60901840e-02, 2.49824246e-01],
#        [9.59802301e-02, 2.51804805e-01],
#        [9.58750537e-02, 2.53739511e-01],
#        [9.57743459e-02, 2.55630429e-01],
#        [9.56778241e-02, 2.57479489e-01],
#        [9.55852292e-02, 2.59288495e-01],
#        [9.54963232e-02, 2.61059140e-01],
#        [9.54108869e-02, 2.62793009e-01],
#        [9.53287184e-02, 2.64491594e-01],
#        [9.52496312e-02, 2.66156295e-01],
#        [9.51734528e-02, 2.67788433e-01],
#        [9.51000235e-02, 2.69389252e-01],
#        [9.50291952e-02, 2.70959928e-01],
#        [9.49608300e-02, 2.72501569e-01],
#        [9.48948001e-02, 2.74015227e-01],
#        [9.48309861e-02, 2.75501895e-01],
#        [9.47692767e-02, 2.76962516e-01],
#        [9.47095681e-02, 2.78397982e-01],
#        [9.46517633e-02, 2.79809144e-01],
#        [9.45957712e-02, 2.81196807e-01],
#        [9.45415069e-02, 2.82561739e-01],
#        [9.44888904e-02, 2.83904670e-01],
#        [9.44378468e-02, 2.85226295e-01],
#        [9.43883055e-02, 2.86527277e-01],
#        [9.43402004e-02, 2.87808251e-01],
#        [9.42934689e-02, 2.89069819e-01],
#        [9.42480522e-02, 2.90312559e-01],
#        [9.42038949e-02, 2.91537024e-01],
#        [9.41609445e-02, 2.92743741e-01],
#        [9.41191515e-02, 2.93933215e-01],
#        [9.40784691e-02, 2.95105932e-01],
#        [9.40388530e-02, 2.96262355e-01],
#        [9.40002612e-02, 2.97402929e-01],
#        [9.39626540e-02, 2.98528083e-01],
#        [9.39259935e-02, 2.99638225e-01],
#        [9.38902440e-02, 3.00733751e-01],
#        [9.38553714e-02, 3.01815039e-01],
#        [9.38213435e-02, 3.02882453e-01],
#        [9.37881294e-02, 3.03936344e-01],
#        [9.37557000e-02, 3.04977050e-01],
#        [9.37240272e-02, 3.06004894e-01],
#        [9.36930846e-02, 3.07020192e-01],
#        [9.36628468e-02, 3.08023243e-01],
#        [9.36332897e-02, 3.09014340e-01],
#        [9.36043902e-02, 3.09993763e-01],
#        [9.35761264e-02, 3.10961784e-01],
#        [9.35484770e-02, 3.11918664e-01],
#        [9.35214221e-02, 3.12864655e-01],
#        [9.34949424e-02, 3.13800004e-01],
#        [9.34690195e-02, 3.14724945e-01],
#        [9.34436357e-02, 3.15639707e-01],
#        [9.34187742e-02, 3.16544511e-01],
#        [9.33944187e-02, 3.17439571e-01],
#        [9.33705538e-02, 3.18325095e-01],
#        [9.33471646e-02, 3.19201283e-01],
#        [9.33242367e-02, 3.20068329e-01]])

# %%
# -------------- PART 0a: CHOOSE CIRCUIT AND SET UP FOLDER --------------                            #<--------- SAME AS CODE1 UP TO...

# Choose circuit
circuit = "arneg"

# Import circuit config file
config = importlib.import_module(circuit)

# Define subfolder name to work in
folder_name = f"MOSA_{circuit}"

# Create folder if not yet exist
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Jump to folder
os.chdir(folder_name)

# Prompt new folder name
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /Users/nt625/Documents/GitHub/My5thMOSArepository_plsdontcrash/OneSpeciesCircuits/MOSA_arneg

# %%
# -------------- PART 0d: CHOOSE SENSITIVITY FUNCTIONS --------------                                #<--------- SAME AS CODE1 UP TO...

# Print prompt
print("""
Only two sensitivity functions are present:
0. |S_alpha_xss|
1. |S_n_xss|
MOSA will anneal this pair.
""")

# Choose pair of functions
choice1 = 0
choice2 = 1

# List of sensitivity function names
sensitivity_labels = [
    "|S_alpha_xss|",
    "|S_n_xss|"]

# Save function names for later use
label1 = sensitivity_labels[choice1]
label2 = sensitivity_labels[choice2]


# -------------- PART 0e: CHANGING DIRECTORIES --------------


# Define subfolder name to work in
subfolder_name = f"MOSA_sensfuncs_{choice1}_and_{choice2}/data"

# Create folder if not yet exist
if not os.path.exists(subfolder_name):
    os.makedirs(subfolder_name)

# Jump to folder
os.chdir(subfolder_name)

# Prompt new folder name
print(f"Current working directory: {os.getcwd()}")                                                   #<--------- ...UP TO HERE
# Out:
# Only two sensitivity functions are present:
# 0. |S_alpha_xss|
# 1. |S_n_xss|
# MOSA will anneal this pair.
#
# Current working directory: /Users/nt625/Documents/GitHub/My5thMOSArepository_plsdontcrash/OneSpeciesCircuits/MOSA_arneg/MOSA_sensfuncs_0_and_1/data

# %%
# -------------------- NEW STUFF --------------------

# %%
runs = int(200)
runs
# Out:
# 200

# %%
# Loop through runs
for run in range(1, runs + 1):
    # Load the parameter values for that run's Pareto front
    pareto_Salpha = np.load(f"pareto_Salpha_run{run}.npy", allow_pickle=True)
    pareto_Sn = np.load(f"pareto_Sn_run{run}.npy", allow_pickle=True)

    # Stack the two arrays as columns
    pareto_front = np.column_stack((pareto_Salpha, pareto_Sn))

    # There may be NaNs in the array. Pareto minimisation will think NaNs are minimum. We don't want this. Let's replace NaNs with infinities.
    pareto_front = np.where(np.isnan(pareto_front), np.inf, pareto_front)

    # Compute mask
    mask = paretoset(pareto_front, sense=["min", "min"])

    print(f"Run: {run}")
    if sum(mask) == len(pareto_Salpha):
        print("is good")
# Out:
# Run: 1
# is good
# Run: 2
# is good
# Run: 3
# is good
# Run: 4
# is good
# Run: 5
# is good
# Run: 6
# is good
# Run: 7
# is good
# Run: 8
# is good
# Run: 9
# is good
# Run: 10
# is good
# Run: 11
# is good
# Run: 12
# is good
# Run: 13
# is good
# Run: 14
# is good
# Run: 15
# is good
# Run: 16
# is good
# Run: 17
# is good
# Run: 18
# is good
# Run: 19
# is good
# Run: 20
# is good
# Run: 21
# is good
# Run: 22
# is good
# Run: 23
# is good
# Run: 24
# is good
# Run: 25
# is good
# Run: 26
# is good
# Run: 27
# is good
# Run: 28
# is good
# Run: 29
# is good
# Run: 30
# is good
# Run: 31
# is good
# Run: 32
# is good
# Run: 33
# is good
# Run: 34
# is good
# Run: 35
# is good
# Run: 36
# is good
# Run: 37
# is good
# Run: 38
# is good
# Run: 39
# is good
# Run: 40
# is good
# Run: 41
# is good
# Run: 42
# is good
# Run: 43
# is good
# Run: 44
# is good
# Run: 45
# is good
# Run: 46
# is good
# Run: 47
# is good
# Run: 48
# is good
# Run: 49
# is good
# Run: 50
# is good
# Run: 51
# is good
# Run: 52
# is good
# Run: 53
# is good
# Run: 54
# is good
# Run: 55
# is good
# Run: 56
# is good
# Run: 57
# is good
# Run: 58
# is good
# Run: 59
# is good
# Run: 60
# is good
# Run: 61
# is good
# Run: 62
# is good
# Run: 63
# is good
# Run: 64
# is good
# Run: 65
# is good
# Run: 66
# is good
# Run: 67
# is good
# Run: 68
# is good
# Run: 69
# is good
# Run: 70
# is good
# Run: 71
# is good
# Run: 72
# is good
# Run: 73
# is good
# Run: 74
# is good
# Run: 75
# is good
# Run: 76
# is good
# Run: 77
# is good
# Run: 78
# is good
# Run: 79
# is good
# Run: 80
# is good
# Run: 81
# is good
# Run: 82
# is good
# Run: 83
# is good
# Run: 84
# is good
# Run: 85
# is good
# Run: 86
# is good
# Run: 87
# is good
# Run: 88
# is good
# Run: 89
# is good
# Run: 90
# is good
# Run: 91
# is good
# Run: 92
# is good
# Run: 93
# is good
# Run: 94
# is good
# Run: 95
# is good
# Run: 96
# is good
# Run: 97
# is good
# Run: 98
# is good
# Run: 99
# is good
# Run: 100
# is good
# Run: 101
# is good
# Run: 102
# is good
# Run: 103
# is good
# Run: 104
# is good
# Run: 105
# is good
# Run: 106
# is good
# Run: 107
# is good
# Run: 108
# is good
# Run: 109
# is good
# Run: 110
# is good
# Run: 111
# is good
# Run: 112
# is good
# Run: 113
# is good
# Run: 114
# is good
# Run: 115
# is good
# Run: 116
# is good
# Run: 117
# is good
# Run: 118
# is good
# Run: 119
# is good
# Run: 120
# is good
# Run: 121
# is good
# Run: 122
# is good
# Run: 123
# is good
# Run: 124
# is good
# Run: 125
# is good
# Run: 126
# is good
# Run: 127
# is good
# Run: 128
# is good
# Run: 129
# is good
# Run: 130
# is good
# Run: 131
# is good
# Run: 132
# is good
# Run: 133
# is good
# Run: 134
# is good
# Run: 135
# is good
# Run: 136
# is good
# Run: 137
# is good
# Run: 138
# is good
# Run: 139
# is good
# Run: 140
# is good
# Run: 141
# is good
# Run: 142
# is good
# Run: 143
# is good
# Run: 144
# is good
# Run: 145
# is good
# Run: 146
# is good
# Run: 147
# is good
# Run: 148
# is good
# Run: 149
# is good
# Run: 150
# is good
# Run: 151
# is good
# Run: 152
# is good
# Run: 153
# is good
# Run: 154
# is good
# Run: 155
# is good
# Run: 156
# is good
# Run: 157
# is good
# Run: 158
# is good
# Run: 159
# is good
# Run: 160
# is good
# Run: 161
# is good
# Run: 162
# is good
# Run: 163
# is good
# Run: 164
# is good
# Run: 165
# is good
# Run: 166
# is good
# Run: 167
# is good
# Run: 168
# is good
# Run: 169
# is good
# Run: 170
# is good
# Run: 171
# is good
# Run: 172
# is good
# Run: 173
# is good
# Run: 174
# is good
# Run: 175
# is good
# Run: 176
# is good
# Run: 177
# is good
# Run: 178
# is good
# Run: 179
# is good
# Run: 180
# is good
# Run: 181
# is good
# Run: 182
# is good
# Run: 183
# is good
# Run: 184
# is good
# Run: 185
# is good
# Run: 186
# is good
# Run: 187
# is good
# Run: 188
# is good
# Run: 189
# is good
# Run: 190
# is good
# Run: 191
# is good
# Run: 192
# is good
# Run: 193
# is good
# Run: 194
# is good
# Run: 195
# is good
# Run: 196
# is good
# Run: 197
# is good
# Run: 198
# is good
# Run: 199
# is good
# Run: 200
# is good

# %%
# Sequence to store Pareto front matrices (each matrix is n x 2)
pareto_front_sequence = []
# Sequence to store Pareto paremeter matrices (each matrix is n x 2)
pareto_param_sequence = []

# Loop through runs
for run in range(1, runs + 1):
    AllParetoFrontsUpToCurrentRun = np.empty((0, 2))  # Initialize an empty array
    AllParetoParamsUpToCurrentRun = np.empty((0, 2))  # Initialize an empty array

    # Accumulate data from the first run up to the current run
    for i in range(1, run + 1):

        pareto_Salpha = np.load(f"pareto_Salpha_run{i}.npy", allow_pickle=True)
        pareto_Sn = np.load(f"pareto_Sn_run{i}.npy", allow_pickle=True)

        CurrentParetoFront = np.column_stack((pareto_Salpha, pareto_Sn))
        AllParetoFrontsUpToCurrentRun = np.vstack((AllParetoFrontsUpToCurrentRun, CurrentParetoFront))

        pareto_alpha = np.load(f"pareto_alpha_run{i}.npy", allow_pickle=True)
        pareto_n     = np.load(f"pareto_n_run{i}.npy", allow_pickle=True)

        CurrentParetoParam = np.column_stack((pareto_alpha, pareto_n))
        AllParetoParamsUpToCurrentRun = np.vstack((AllParetoParamsUpToCurrentRun, CurrentParetoParam))

    # Compute Pareto-optimal points
    mask = paretoset(AllParetoFrontsUpToCurrentRun, sense=["min", "min"])
    filteredfront = AllParetoFrontsUpToCurrentRun[mask]
    filteredparam = AllParetoParamsUpToCurrentRun[mask]

    # Store the Pareto front and pareto parameters for this run in the sequence
    pareto_front_sequence.append(filteredfront)
    pareto_param_sequence.append(filteredparam)

# Convert to NumPy object array (variable-sized slices)
pareto_front_sequence = np.array(pareto_front_sequence, dtype=object)
pareto_param_sequence = np.array(pareto_param_sequence, dtype=object)

print("Shape of pareto_front_sequence:", np.shape(pareto_front_sequence))
print("Shape of pareto_param_sequence:", np.shape(pareto_param_sequence))
# Out:
# Shape of pareto_front_sequence: (200,)
# Shape of pareto_param_sequence: (200,)

# %%
GDs = []

# Loop through runs
for run in range(runs):
    
    pf = pareto_front_sequence[run]
    ind = GD(pf)
    gd_value = ind(gridsearchdata)

    # Store moment of inertia
    GDs.append(gd_value)

# Plot Moment of Inertia over Runs
plt.figure(figsize=(8, 5))
plt.plot(range(1, runs + 1), GDs)
plt.xlabel("Run Number")
plt.ylabel("Generational Distance")
plt.title("Evolution of Generational Distance Across Runs")
plt.grid()

# Save and show
plt.show()

# %%
# Specify which runs you want to include
selected_runs = [1, 25, 100, 200]  # Can be any number of runs

# Generate a unique color for each run using a colormap
cmap = cm.get_cmap("tab10", len(selected_runs))  # Choose a colormap and get distinct colors
color_map = {run: cmap(i) for i, run in enumerate(selected_runs)}

# Define marker size reduction (larger for earlier runs, smaller for later ones)
marker_sizes = {run: size for run, size in zip(selected_runs, np.linspace(70, 10, len(selected_runs)))}  # Adjust dynamically

plt.figure(figsize=(8, 6))

# Loop through only selected runs
for i, run in enumerate(selected_runs):
    # Retrieve the precomputed Pareto front for this run
    # Convert to 0-based index
    filteredfront = pareto_front_sequence[run - 1]

    # Scatter plot for this specific run with adjusted marker size and color
    plt.scatter(filteredfront[:, 0], filteredfront[:, 1], 
                color=color_map[run], label=f"Run {run}", marker="x", s=marker_sizes[run], alpha=0.8)

# Plot grid search Pareto front
plt.scatter(gridsearchdata[:,0], gridsearchdata[:,1], marker=".", s=5, color = "black", alpha=0.7, label="grid search")

# Labels and legend
plt.xlabel(label1)
plt.ylabel(label2)
plt.title(f"Pareto Front Evolution")
plt.legend()
plt.grid()

# Save and show figure
plt.show()
# Out:
# /var/folders/00/1d6xmh4s561gn38h3vf1mlyh005mvp/T/ipykernel_7365/3467371532.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap("tab10", len(selected_runs))  # Choose a colormap and get distinct colors
