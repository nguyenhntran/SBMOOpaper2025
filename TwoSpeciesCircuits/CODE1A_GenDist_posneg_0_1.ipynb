# %%
# Import packages
import importlib
import os
import time
import numpy as np
import gc
import mosa
from paretoset import paretoset
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Needed for 3D plots
from pymoo.indicators.gd import GD

# %%
# Import grid search data
data = np.load('../GridSearchData/PositiveNegative_SensitivityPairsParetos.npz')
print(data.files)

key = "paretoset_SensPair1" #<------ edit this line

gridsearchdata = data[key]
print(key, ": \n", gridsearchdata)
# Out:
# ['paretoset_SensPair1', 'paretoset_SensPair2', 'paretoset_SensPair3', 'paretoset_SensPair4', 'paretoset_SensPair5', 'paretoset_SensPair6', 'paretoset_SensPair7', 'paretoset_SensPair8', 'paretoset_SensPair9', 'paretoset_SensPair10', 'paretoset_SensPair11', 'paretoset_SensPair12', 'paretoset_SensPair13', 'paretoset_SensPair14', 'paretoset_SensPair15']
# paretoset_SensPair1 :
#  [[9.99998106e-01 2.34470555e-07]
#  [9.99998121e-01 2.33997252e-07]
#  [9.99998131e-01 2.32299045e-07]
#  ...
#  [1.49632539e-02 1.00373215e-01]
#  [1.48523262e-02 1.00380144e-01]
#  [1.03551183e-02 1.00385446e-01]]

# %%
# -------------- PART 0a: CHOOSE CIRCUIT AND SET UP FOLDER --------------                            #<--------- SAME AS CODE1 UP TO...

# Choose circuit
circuit = "posneg"

# Import circuit config file
config = importlib.import_module(circuit)

# Define subfolder name to work in
folder_name = f"MOSA_{circuit}"

# Create folder if not yet exist
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Jump to folder
os.chdir(folder_name)

# Prompt new folder name
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /Users/nt625/Documents/GitHub/My5thMOSArepository_plsdontcrash/TwoSpeciesCircuits/MOSA_posneg

# %%
# -------------- PART 0d: CHOOSE SENSITIVITY FUNCTIONS --------------

# Print prompt
print("""
We have the following sensitivity functions:
0. |S_betax_xss|
1. |S_betax_yss|
2. |S_betay_xss|
3. |S_betay_yss|
4. |S_n_xss|
5. |S_n_yss|
""")

# Choose pair of functions
choice1 = int(0)
choice2 = int(1)

# List of sensitivity function names

sensitivity_labels = [
    "|S_betax_xss|",
    "|S_betax_yss|",
    "|S_betay_xss|",
    "|S_betay_yss|",
    "|S_n_xss|",
    "|S_n_yss|"]

sensitivity_labels_latex = [
    r"$|S_{\beta_x}(x_{ss})|$",
    r"$|S_{\beta_x}(y_{ss})|$",
    r"$|S_{\beta_y}(x_{ss})|$",
    r"$|S_{\beta_y}(y_{ss})|$",
    r"$|S_{n}(x_{ss})|$",
    r"$|S_{n}(y_{ss})|$"]

# Save function names for later use

label1 = sensitivity_labels[choice1]
label2 = sensitivity_labels[choice2]

label1_latex = sensitivity_labels_latex[choice1]
label2_latex = sensitivity_labels_latex[choice2]
# Out:
# We have the following sensitivity functions:
# 0. |S_betax_xss|
# 1. |S_betax_yss|
# 2. |S_betay_xss|
# 3. |S_betay_yss|
# 4. |S_n_xss|
# 5. |S_n_yss|

# %%
# -------------- PART 0e: CHANGING DIRECTORIES --------------

# Define the subfolder name
subfolder_name = f"MOSA_sensfuncs_{choice1}_and_{choice2}/data"

# Jump to folder
os.chdir(subfolder_name)

# Prompt new folder name
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /Users/nt625/Documents/GitHub/My5thMOSArepository_plsdontcrash/TwoSpeciesCircuits/MOSA_posneg/MOSA_sensfuncs_0_and_1/data

# %%
# -------------------- NEW STUFF --------------------

# %%
runs = int(200)
runs
# Out:
# 200

# %%
# Loop through runs
for run in range(1, runs + 1):
    # Load the parameter values for that run's Pareto front
    pareto_sensfunc1 = np.load(f"pareto_sensfunc1_run{run}.npy", allow_pickle=True)
    pareto_sensfunc2 = np.load(f"pareto_sensfunc2_run{run}.npy", allow_pickle=True)

    # Stack the two arrays as columns
    pareto_front = np.column_stack((pareto_sensfunc1, pareto_sensfunc2))

    # There may be NaNs in the array. Pareto minimisation will think NaNs are minimum. We don't want this. Let's replace NaNs with infinities.
    pareto_front = np.where(np.isnan(pareto_front), np.inf, pareto_front)

    # Compute mask
    mask = paretoset(pareto_front, sense=["min", "min"])

    print(f"Run: {run}")
    if sum(mask) == len(pareto_sensfunc1):
        print("is good")
# Out:
# Run: 1
# is good
# Run: 2
# is good
# Run: 3
# is good
# Run: 4
# is good
# Run: 5
# is good
# Run: 6
# is good
# Run: 7
# is good
# Run: 8
# is good
# Run: 9
# is good
# Run: 10
# is good
# Run: 11
# is good
# Run: 12
# is good
# Run: 13
# is good
# Run: 14
# is good
# Run: 15
# is good
# Run: 16
# is good
# Run: 17
# is good
# Run: 18
# is good
# Run: 19
# is good
# Run: 20
# is good
# Run: 21
# is good
# Run: 22
# is good
# Run: 23
# is good
# Run: 24
# is good
# Run: 25
# is good
# Run: 26
# is good
# Run: 27
# is good
# Run: 28
# is good
# Run: 29
# is good
# Run: 30
# is good
# Run: 31
# is good
# Run: 32
# is good
# Run: 33
# is good
# Run: 34
# is good
# Run: 35
# is good
# Run: 36
# is good
# Run: 37
# is good
# Run: 38
# is good
# Run: 39
# is good
# Run: 40
# is good
# Run: 41
# is good
# Run: 42
# is good
# Run: 43
# is good
# Run: 44
# is good
# Run: 45
# is good
# Run: 46
# is good
# Run: 47
# is good
# Run: 48
# is good
# Run: 49
# is good
# Run: 50
# is good
# Run: 51
# is good
# Run: 52
# is good
# Run: 53
# is good
# Run: 54
# is good
# Run: 55
# is good
# Run: 56
# is good
# Run: 57
# is good
# Run: 58
# is good
# Run: 59
# is good
# Run: 60
# is good
# Run: 61
# is good
# Run: 62
# is good
# Run: 63
# is good
# Run: 64
# is good
# Run: 65
# is good
# Run: 66
# is good
# Run: 67
# is good
# Run: 68
# is good
# Run: 69
# is good
# Run: 70
# is good
# Run: 71
# is good
# Run: 72
# is good
# Run: 73
# is good
# Run: 74
# is good
# Run: 75
# is good
# Run: 76
# is good
# Run: 77
# is good
# Run: 78
# is good
# Run: 79
# is good
# Run: 80
# is good
# Run: 81
# is good
# Run: 82
# is good
# Run: 83
# is good
# Run: 84
# is good
# Run: 85
# is good
# Run: 86
# is good
# Run: 87
# is good
# Run: 88
# is good
# Run: 89
# is good
# Run: 90
# is good
# Run: 91
# is good
# Run: 92
# is good
# Run: 93
# is good
# Run: 94
# is good
# Run: 95
# is good
# Run: 96
# is good
# Run: 97
# is good
# Run: 98
# is good
# Run: 99
# is good
# Run: 100
# is good
# Run: 101
# is good
# Run: 102
# is good
# Run: 103
# is good
# Run: 104
# is good
# Run: 105
# is good
# Run: 106
# is good
# Run: 107
# is good
# Run: 108
# is good
# Run: 109
# is good
# Run: 110
# is good
# Run: 111
# is good
# Run: 112
# is good
# Run: 113
# is good
# Run: 114
# is good
# Run: 115
# is good
# Run: 116
# is good
# Run: 117
# is good
# Run: 118
# is good
# Run: 119
# is good
# Run: 120
# is good
# Run: 121
# is good
# Run: 122
# is good
# Run: 123
# is good
# Run: 124
# is good
# Run: 125
# is good
# Run: 126
# is good
# Run: 127
# is good
# Run: 128
# is good
# Run: 129
# is good
# Run: 130
# is good
# Run: 131
# is good
# Run: 132
# is good
# Run: 133
# is good
# Run: 134
# is good
# Run: 135
# is good
# Run: 136
# is good
# Run: 137
# is good
# Run: 138
# is good
# Run: 139
# is good
# Run: 140
# is good
# Run: 141
# is good
# Run: 142
# is good
# Run: 143
# is good
# Run: 144
# is good
# Run: 145
# is good
# Run: 146
# is good
# Run: 147
# is good
# Run: 148
# is good
# Run: 149
# is good
# Run: 150
# is good
# Run: 151
# is good
# Run: 152
# is good
# Run: 153
# is good
# Run: 154
# is good
# Run: 155
# is good
# Run: 156
# is good
# Run: 157
# is good
# Run: 158
# is good
# Run: 159
# is good
# Run: 160
# is good
# Run: 161
# is good
# Run: 162
# is good
# Run: 163
# is good
# Run: 164
# is good
# Run: 165
# is good
# Run: 166
# is good
# Run: 167
# is good
# Run: 168
# is good
# Run: 169
# is good
# Run: 170
# is good
# Run: 171
# is good
# Run: 172
# is good
# Run: 173
# is good
# Run: 174
# is good
# Run: 175
# is good
# Run: 176
# is good
# Run: 177
# is good
# Run: 178
# is good
# Run: 179
# is good
# Run: 180
# is good
# Run: 181
# is good
# Run: 182
# is good
# Run: 183
# is good
# Run: 184
# is good
# Run: 185
# is good
# Run: 186
# is good
# Run: 187
# is good
# Run: 188
# is good
# Run: 189
# is good
# Run: 190
# is good
# Run: 191
# is good
# Run: 192
# is good
# Run: 193
# is good
# Run: 194
# is good
# Run: 195
# is good
# Run: 196
# is good
# Run: 197
# is good
# Run: 198
# is good
# Run: 199
# is good
# Run: 200
# is good

# %%
# Sequence to store Pareto front matrices (each matrix is n x 2)
pareto_front_sequence = []
# Sequence to store Pareto paremeter matrices (each matrix is n x 3)
pareto_param_sequence = []

# Loop through runs
for run in range(1, runs + 1):
    AllParetoFrontsUpToCurrentRun = np.empty((0, 2))  # Initialize an empty array
    AllParetoParamsUpToCurrentRun = np.empty((0, 3))  # Initialize an empty array

    # Accumulate data from the first run up to the current run
    for i in range(1, run + 1):

        pareto_sensfunc1 = np.load(f"pareto_sensfunc1_run{i}.npy", allow_pickle=True)
        pareto_sensfunc2 = np.load(f"pareto_sensfunc2_run{i}.npy", allow_pickle=True)

        CurrentParetoFront = np.column_stack((pareto_sensfunc1, pareto_sensfunc2))
        AllParetoFrontsUpToCurrentRun = np.vstack((AllParetoFrontsUpToCurrentRun, CurrentParetoFront))

        pareto_betax = np.load(f"pareto_betax_run{i}.npy", allow_pickle=True)
        pareto_betay = np.load(f"pareto_betay_run{i}.npy", allow_pickle=True)
        pareto_n     = np.load(f"pareto_n_run{i}.npy", allow_pickle=True)

        CurrentParetoParam = np.column_stack((pareto_betax, pareto_betay, pareto_n))
        AllParetoParamsUpToCurrentRun = np.vstack((AllParetoParamsUpToCurrentRun, CurrentParetoParam))

    # Compute Pareto-optimal points
    mask = paretoset(AllParetoFrontsUpToCurrentRun, sense=["min", "min"])
    filteredfront = AllParetoFrontsUpToCurrentRun[mask]
    filteredparam = AllParetoParamsUpToCurrentRun[mask]

    # Store the Pareto front and pareto parameters for this run in the sequence
    pareto_front_sequence.append(filteredfront)
    pareto_param_sequence.append(filteredparam)

# Convert to NumPy object array (variable-sized slices)
pareto_front_sequence = np.array(pareto_front_sequence, dtype=object)
pareto_param_sequence = np.array(pareto_param_sequence, dtype=object)

print("Shape of pareto_front_sequence:", np.shape(pareto_front_sequence))
print("Shape of pareto_param_sequence:", np.shape(pareto_param_sequence))
# Out:
# Shape of pareto_front_sequence: (200,)
# Shape of pareto_param_sequence: (200,)

# %%
GDs = []

# Loop through runs
for run in range(runs):
    
    pf = pareto_front_sequence[run]
    ind = GD(pf)
    gd_value = ind(gridsearchdata)

    # Store moment of inertia
    GDs.append(gd_value)

# %%
# Plot GDs
plt.figure(figsize=(5, 5), dpi=300)
plt.plot(range(1, runs + 1), GDs)
plt.xlabel("Number of runs")
plt.ylabel("Generational Distance (unitless)")
plt.title("Positive-Negative Feedback: Generational Distances")

# Save and show
plt.show()

# %%
# Plot GDs
plt.figure(figsize=(3,3), dpi=300)
plt.plot(range(1, runs + 1), GDs)
plt.xlim([-0.001,75])
plt.ylim([-0.001,0.1])
plt.show()

# %%
# Specify which runs you want to include
selected_runs = [1, 5, 15, 50, 100, 200]  # Can be any number of runs

# Generate a unique color for each run using a colormap
cmap = cm.get_cmap("tab10", len(selected_runs))  # Choose a colormap and get distinct colors
color_map = {run: cmap(i) for i, run in enumerate(selected_runs)}

# Define marker size reduction (larger for earlier runs, smaller for later ones)
marker_sizes = {run: size for run, size in zip(selected_runs, np.linspace(70, 10, len(selected_runs)))}  # Adjust dynamically

plt.figure(figsize=(5,5), dpi=300)

# Loop through only selected runs
for i, run in enumerate(selected_runs):
    # Retrieve the precomputed Pareto front for this run
    # Convert to 0-based index
    filteredfront = pareto_front_sequence[run - 1]

    # Scatter plot for this specific run with adjusted marker size and color
    plt.scatter(filteredfront[:, 0], filteredfront[:, 1], 
                color=color_map[run], label=f"Run {run}", marker=".", s=marker_sizes[run], alpha=0.8)

# Plot grid search Pareto front
plt.scatter(gridsearchdata[:,0], gridsearchdata[:,1], marker=".", s=1, color = "black", alpha=0.7, label="grid search")

# Labels and legend
plt.xlabel(label1_latex)
plt.ylabel(label2_latex)
plt.title(f"Positive-Negative Feedback: Pareto Front Evolution")
plt.legend()

# Save and show figure
plt.show()
# Out:
# /var/folders/00/1d6xmh4s561gn38h3vf1mlyh005mvp/T/ipykernel_29460/2049656850.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap("tab10", len(selected_runs))  # Choose a colormap and get distinct colors

# %%
# Create a 3D plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Loop through only selected runs
for run in selected_runs:
    # Retrieve the corresponding parameter set for this run
    parameter_values = pareto_param_sequence[run - 1]  # Convert to 0-based index

    # Scatter plot for the parameter values
    ax.scatter(parameter_values[:, 0], parameter_values[:, 1], parameter_values[:, 2], 
               color=color_map[run], label=f"Run {run}", marker="+", s=marker_sizes[run], alpha=0.8)

# Labels and legend
ax.set_xlabel(r"$\beta_x$")
ax.set_ylabel(r"$\beta_y$")
ax.set_zlabel(r"$n$")
ax.set_title(f"Corresponding Parameters")
ax.legend()
plt.grid()

# Save and show figure
plt.show()
